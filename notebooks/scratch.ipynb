# %% [markdown]
# # Scratch Canvas
#
# Free-form coding space for the gender-wage-gap-analysis project.
#
# **Conventions:**
# - This notebook is for exploration and practice, not for final analytical outputs.
# - Phase boundaries still apply: do not modify raw data, do not pre-compute Phase 3 statistics during Phase 1/2 work.
# - When something here graduates into real project work, move it to the appropriate location (`scripts/`, a dedicated notebook, or a Phase 2 normalization module).

# %% [markdown]
# ## Environment check
#
# Run the cell below to confirm the kernel and core libraries work, and that the project's processed datasets are reachable.

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

REPO_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_PROCESSED = REPO_ROOT / "data" / "processed"

print(f"Python: {sys.version.split()[0]}")
print(f"pandas: {pd.__version__}")
print(f"numpy:  {np.__version__}")
print(f"Repo root:        {REPO_ROOT}")
print(f"Processed data:   {DATA_PROCESSED}")
print(f"Datasets found:   {sorted(p.name for p in DATA_PROCESSED.glob('*.csv'))}")

# %% [markdown]
# ## Load a dataset to confirm I/O works

# %%
df = pd.read_csv(DATA_PROCESSED / "integrated_wage_data_validated.csv")
print(df.shape)
df.head()

# %% [markdown]
# ## Your scratch space below
#
# Add cells here. Suggested practice topics:
# - Inspect the WBL raw XLSX (Phase 1 file-level only — no value transformations)
# - Sketch a country-code harmonisation function (ISO-3 mapping)
# - Practice pandas reshaping (long ↔ wide for country-year panels)
# - Try a simple OLS fit using `statsmodels`
